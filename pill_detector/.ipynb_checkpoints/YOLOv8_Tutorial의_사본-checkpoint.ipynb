# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.57-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.8/486.8 kB 9.6 MB/s eta 0:00:00m eta 0:00:01
# Collecting numpy>=1.21.6
#   Downloading numpy-1.24.2-cp310-cp310-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 11.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting requests>=2.23.0
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting pandas>=1.1.4
#   Downloading pandas-1.5.3-cp310-cp310-macosx_10_9_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 12.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting tqdm>=4.64.0
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.7 MB/s eta 0:00:00
# Collecting sentry-sdk
#   Downloading sentry_sdk-1.17.0-py2.py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 kB 10.7 MB/s eta 0:00:00
# Collecting opencv-python>=4.6.0
#   Downloading opencv_python-4.7.0.72-cp37-abi3-macosx_10_16_x86_64.whl (53.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 MB 10.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting scipy>=1.4.1
#   Downloading scipy-1.10.1-cp310-cp310-macosx_10_9_x86_64.whl (35.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.1/35.1 MB 11.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting seaborn>=0.11.0
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting matplotlib>=3.2.2
#   Downloading matplotlib-3.7.1-cp310-cp310-macosx_10_12_x86_64.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 11.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: psutil in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from ultralytics) (5.9.4)
# Collecting Pillow>=7.1.2
#   Downloading Pillow-9.4.0-2-cp310-cp310-macosx_10_10_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting torch>=1.7.0
#   Downloading torch-2.0.0-cp310-none-macosx_10_9_x86_64.whl (139.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 MB 7.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting torchvision>=0.8.1
#   Downloading torchvision-0.15.1-cp310-cp310-macosx_10_9_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.5 MB/s eta 0:00:0031m13.2 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics) (23.0)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.2-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp310-cp310-macosx_10_9_x86_64.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 9.2 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2022.7.1)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.1.0-cp310-cp310-macosx_10_9_x86_64.whl (124 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Collecting typing-extensions
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 12.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting networkx
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.7 MB/s eta 0:00:0031m13.1 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.10.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: jinja2 in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from torch>=1.7.0->ultralytics) (3.1.2)
# Requirement already satisfied: six>=1.5 in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sonhaechang/opt/miniconda3/envs/pill_detector/lib/python3.10/site-packages (from jinja2->torch>=1.7.0->ultralytics) (2.1.2)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 11.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: mpmath, urllib3, typing-extensions, tqdm, sympy, pyparsing, Pillow, numpy, networkx, kiwisolver, fonttools, filelock, cycler, charset-normalizer, torch, sentry-sdk, scipy, requests, pandas, opencv-python, contourpy, torchvision, thop, matplotlib, seaborn, ultralytics

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
# Downloading https://ultralytics.com/images/bus.jpg to bus.jpg...
#   0%|          | 0.00/476k [00:00<?, ?B/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 13.9ms
# Speed: 0.6ms preprocess, 13.9ms inference, 39.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
results[0].boxes.cls
# Out:
# tensor([ 5.,  0.,  0.,  0., 11.,  0.], device='cuda:0')
